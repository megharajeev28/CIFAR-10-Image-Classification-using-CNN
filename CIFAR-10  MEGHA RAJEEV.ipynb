# %% [markdown]
# # CIFAR-10 Image Classification using CNN
#
# **Name:** MEGHA RAJEEV
# **Reg No:** 23MIM10047
#
# **Objective:** Build a Convolutional Neural Network (CNN) to classify images from the CIFAR-10 dataset into 10 categories with a target accuracy of 85%.
#
# **Dataset:** CIFAR-10 — 50,000 training images, 10,000 test images, 32×32×3 (RGB)

# %%
# installing all the required libraries
# !pip install tensorflow matplotlib numpy scipy scikit-learn seaborn
# Out:
# Requirement already satisfied: tensorflow in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (2.16.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (3.10.9)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (1.15.3)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: seaborn in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (4.25.9)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (1.81.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (3.12.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.19.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)

# %%
# importing the necessary libraries
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.16.2

# %%
# loading cifar-10 dataset (already split into train and test)
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

# checking the shape of training and test data
print("Training data shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test data shape:", x_test.shape)
print("Test labels shape:", y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 602s 4us/step
# Training data shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test data shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)

# %%
# cifar-10 has 10 categories
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer',
               'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# lets visualize some images from the dataset to understand it better
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i])
    plt.xlabel(class_names[y_train[i][0]])
plt.suptitle("Sample Images from CIFAR-10 Dataset", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# normalizing pixel values to be between 0 and 1 (originally 0-255)
x_train = x_train / 255.0
x_test = x_test / 255.0

print("Pixel value range after normalization:")
print("Min:", x_train.min(), "Max:", x_train.max())
# Out:
# Pixel value range after normalization:
# Min: 0.0 Max: 1.0

# %%
# data augmentation - helps the model generalize better and avoid overfitting
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# %%
# building the CNN model with batch normalization and dropout for regularization

model = models.Sequential()

# first conv block - 32 filters
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# second conv block - 64 filters
model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# third conv block - 128 filters
model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# flattening and dense layers
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

# output layer - 10 classes with softmax
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# /opt/anaconda3/envs/cifar_env/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-06-26 16:17:28.567782: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-06-26 16:17:28.567965: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2026-06-26 16:17:28.567982: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2026-06-26 16:17:28.568343: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-06-26 16:17:28.568598: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 552,874 (2.11 MB)
#  Trainable params: 551,722 (2.10 MB)
#  Non-trainable params: 1,152 (4.50 KB)

# %%
# compiling with adam optimizer
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# using learning rate reducer - reduces lr when accuracy plateaus
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

# training with data augmentation for 30 epochs
history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[lr_reducer])
# Out:
# Epoch 1/30
# 2026-06-26 16:17:34.707089: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 57ms/step - accuracy: 0.4102 - loss: 1.6928 - val_accuracy: 0.4633 - val_loss: 1.7255 - learning_rate: 0.0010
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.5788 - loss: 1.1780 - val_accuracy: 0.6617 - val_loss: 0.9737 - learning_rate: 0.0010
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.6457 - loss: 1.0057 - val_accuracy: 0.6732 - val_loss: 0.9403 - learning_rate: 0.0010
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.6870 - loss: 0.8973 - val_accuracy: 0.7002 - val_loss: 0.9105 - learning_rate: 0.0010
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.7089 - loss: 0.8377 - val_accuracy: 0.7210 - val_loss: 0.8409 - learning_rate: 0.0010
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.7310 - loss: 0.7859 - val_accuracy: 0.7284 - val_loss: 0.8330 - learning_rate: 0.0010
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.7425 - loss: 0.7501 - val_accuracy: 0.7576 - val_loss: 0.7031 - learning_rate: 0.0010
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.7549 - loss: 0.7157 - val_accuracy: 0.7866 - val_loss: 0.6410 - learning_rate: 0.0010
# Epoch 9/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.7658 - loss: 0.6867 - val_accuracy: 0.7638 - val_loss: 0.7194 - learning_rate: 0.0010
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.7719 - loss: 0.6729 - val_accuracy: 0.7705 - val_loss: 0.7045 - learning_rate: 0.0010
# Epoch 11/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7778 - loss: 0.6585
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.7791 - loss: 0.6505 - val_accuracy: 0.7690 - val_loss: 0.7321 - learning_rate: 0.0010
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.8004 - loss: 0.5912 - val_accuracy: 0.8147 - val_loss: 0.5465 - learning_rate: 5.0000e-04
# Epoch 13/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.8046 - loss: 0.5710 - val_accuracy: 0.8149 - val_loss: 0.5666 - learning_rate: 5.0000e-04
# Epoch 14/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.8083 - loss: 0.5607 - val_accuracy: 0.8255 - val_loss: 0.5334 - learning_rate: 5.0000e-04
# Epoch 15/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.8155 - loss: 0.5454 - val_accuracy: 0.8307 - val_loss: 0.5053 - learning_rate: 5.0000e-04
# Epoch 16/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.8164 - loss: 0.5396 - val_accuracy: 0.8432 - val_loss: 0.4793 - learning_rate: 5.0000e-04
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.8198 - loss: 0.5328 - val_accuracy: 0.8370 - val_loss: 0.4867 - learning_rate: 5.0000e-04
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.8217 - loss: 0.5252 - val_accuracy: 0.8333 - val_loss: 0.5157 - learning_rate: 5.0000e-04
# Epoch 19/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8227 - loss: 0.5173
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.8231 - loss: 0.5174 - val_accuracy: 0.8213 - val_loss: 0.5528 - learning_rate: 5.0000e-04
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.8329 - loss: 0.4940 - val_accuracy: 0.8530 - val_loss: 0.4350 - learning_rate: 2.5000e-04
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.8362 - loss: 0.4815 - val_accuracy: 0.8505 - val_loss: 0.4549 - learning_rate: 2.5000e-04
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.8382 - loss: 0.4735 - val_accuracy: 0.8576 - val_loss: 0.4271 - learning_rate: 2.5000e-04
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.8383 - loss: 0.4735 - val_accuracy: 0.8571 - val_loss: 0.4228 - learning_rate: 2.5000e-04
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.8419 - loss: 0.4729 - val_accuracy: 0.8575 - val_loss: 0.4356 - learning_rate: 2.5000e-04
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.8418 - loss: 0.4624 - val_accuracy: 0.8539 - val_loss: 0.4548 - learning_rate: 2.5000e-04
# Epoch 26/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8495 - loss: 0.4525
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.8458 - loss: 0.4561 - val_accuracy: 0.8555 - val_loss: 0.4431 - learning_rate: 2.5000e-04
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.8472 - loss: 0.4477 - val_accuracy: 0.8649 - val_loss: 0.4217 - learning_rate: 1.2500e-04
# Epoch 28/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.8495 - loss: 0.4450 - val_accuracy: 0.8601 - val_loss: 0.4305 - learning_rate: 1.2500e-04
# Epoch 29/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.8519 - loss: 0.4385 - val_accuracy: 0.8634 - val_loss: 0.4175 - learning_rate: 1.2500e-04
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.8501 - loss: 0.4410 - val_accuracy: 0.8604 - val_loss: 0.4322 - learning_rate: 1.2500e-04

# %%
# plotting accuracy and loss curves to check for overfitting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# accuracy plot
ax1.plot(history.history['accuracy'], label='Training Accuracy')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Training vs Validation Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True)

# loss plot
ax2.plot(history.history['loss'], label='Training Loss')
ax2.plot(history.history['val_loss'], label='Validation Loss')
ax2.set_title('Training vs Validation Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

print("\nFinal Training Accuracy: {:.2f}%".format(history.history['accuracy'][-1] * 100))
print("Final Validation Accuracy: {:.2f}%".format(history.history['val_accuracy'][-1] * 100))

if history.history['val_accuracy'][-1] >= history.history['accuracy'][-1]:
    print("\n✅ No overfitting detected - validation accuracy is >= training accuracy")
else:
    gap = history.history['accuracy'][-1] - history.history['val_accuracy'][-1]
    if gap < 0.05:
        print("\n✅ No significant overfitting - gap between train and val is only {:.2f}%".format(gap * 100))
    else:
        print("\n⚠️ Possible overfitting - gap is {:.2f}%".format(gap * 100))
# Out:
# Final Training Accuracy: 85.01%
# Final Validation Accuracy: 86.04%
#
# ✅ No overfitting detected - validation accuracy is >= training accuracy

# %%
# evaluating model on test data
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=1)
print("\nTest Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test Loss: {:.4f}".format(test_loss))

# making predictions on some test images
predictions = model.predict(x_test[:10])

# visualizing predictions vs actual labels
plt.figure(figsize=(15, 6))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[i])
    predicted_label = class_names[np.argmax(predictions[i])]
    actual_label = class_names[y_test[i][0]]
    color = 'green' if predicted_label == actual_label else 'red'
    plt.xlabel(f"Pred: {predicted_label}\nActual: {actual_label}", color=color, fontsize=9)
plt.suptitle("Model Predictions (Green = Correct, Red = Wrong)", fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8604 - loss: 0.4322
#
# Test Accuracy: 86.04%
# Test Loss: 0.4322
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step

# %%
# generating classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# getting predictions for all test images
y_pred = np.argmax(model.predict(x_test), axis=1)

# classification report
print("Classification Report:\n")
print(classification_report(y_test, y_pred, target_names=class_names))

# confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix - CIFAR-10 CNN Model')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("\n✅ Final Test Accuracy: {:.2f}% (Target was 85%)".format(test_accuracy * 100))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     Airplane       0.89      0.86      0.87      1000
#   Automobile       0.93      0.94      0.94      1000
#         Bird       0.85      0.80      0.82      1000
#          Cat       0.82      0.65      0.73      1000
#         Deer       0.83      0.86      0.85      1000
#          Dog       0.87      0.73      0.80      1000
#         Frog       0.77      0.96      0.86      1000
#        Horse       0.90      0.91      0.90      1000
#         Ship       0.91      0.94      0.92      1000
#        Truck       0.85      0.95      0.90      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000
# ✅ Final Test Accuracy: 86.04% (Target was 85%)
